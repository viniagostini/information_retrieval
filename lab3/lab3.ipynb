# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
import collections
import seaborn as sns
nltk.download('rslp')
from nltk.stem import RSLPStemmer
# Out:
# [nltk_data] Downloading package rslp to /home/vinicius/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %%
data = pd.read_csv('results.csv')

# %% [markdown]
# ### Questão 1 - Estratégia de tokenização:

# %% [markdown]
# A estratégia de tokenização que decidi utilizar foi considerar apenas palavras de tamanho maior ou igual a 3 caractéres. Isso é bacana porque remove grande parte das palavras mais frequentes da e que geralmente são stopwords.

# %%
#limpa o texto e gera tokens
words = ''.join(str(v) for v in data.texto).lower()
tokens = RegexpTokenizer(r'[A-zÀ-ú\d]{3,}').tokenize(words)

# %% [markdown]
# ### Questão 2:

# %%
docs_count = data.texto.count()
words_count = collections.Counter(tokens)
word_occurrences = sum(words_count.values())
rank = 1
ranks = []
words = []
freqs = []
probs = []
rprobs = []
for word,n in words_count.most_common():
    prob = (n/word_occurrences) * 100
    rprobs.append(rank * prob / 100)
    probs.append(prob)
    words.append(word)
    freqs.append(n)
    ranks.append(rank)
    rank += 1

table42 = pd.DataFrame()
table42['Word'] = words
table42['Freq'] = freqs
table42['r'] = ranks
table42['Pr(%)'] = probs
table42['r.Pr'] = rprobs
table42.head(50)
# Out:
#           Word  Freq   r     Pr(%)      r.Pr
# 0          que  5158   1  4.206697  0.042067
# 1         para  1850   2  1.508800  0.030176
# 2          uma  1752   3  1.428874  0.042866
# 3          com  1734   4  1.414194  0.056568
# 4          não  1535   5  1.251896  0.062595
# 5         como  1080   6  0.880813  0.052849
# 6          por  1076   7  0.877551  0.061429
# 7         mais   940   8  0.766634  0.061331
# 8          dos   834   9  0.680183  0.061217
# 9          mas   731  10  0.596180  0.059618
# 10         sua   710  11  0.579053  0.063696
# 11         foi   604  12  0.492603  0.059112
# 12         seu   602  13  0.490972  0.063826
# 13         das   575  14  0.468951  0.065653
# 14        anos   519  15  0.423280  0.063492
# 15         ser   402  16  0.327858  0.052457
# 16      também   397  17  0.323780  0.055043
# 17         nos   391  18  0.318887  0.057400
# 18        pelo   378  19  0.308285  0.058574
# 19        pela   366  20  0.298498  0.059700
# 20         são   366  21  0.298498  0.062685
# 21      quando   350  22  0.285449  0.062799
# 22         ele   335  23  0.273215  0.062839
# 23       entre   333  24  0.271584  0.065180
# 24       sobre   316  25  0.257719  0.064430
# 25       muito   310  26  0.252826  0.065735
# 26         era   306  27  0.249564  0.067382
# 27      depois   297  28  0.242224  0.067823
# 28        seus   291  29  0.237330  0.068826
# 29        está   289  30  0.235699  0.070710
# 30        isso   282  31  0.229990  0.071297
# 31      brasil   269  32  0.219388  0.070204
# 32       ainda   262  33  0.213679  0.070514
# 33        país   261  34  0.212863  0.072373
# 34         até   257  35  0.209601  0.073360
# 35   bolsonaro   253  36  0.206339  0.074282
# 36  presidente   251  37  0.204707  0.075742
# 37         sem   245  38  0.199814  0.075929
# 38     governo   239  39  0.194921  0.076019
# 39         aos   228  40  0.185949  0.074380
# 40         tem   224  41  0.182687  0.074902
# 41        suas   221  42  0.180240  0.075701
# 42         nas   219  43  0.178609  0.076802
# 43      porque   207  44  0.168822  0.074282
# 44         ter   200  45  0.163114  0.073401
# 45         ano   200  46  0.163114  0.075032
# 46         ela   195  47  0.159036  0.074747
# 47       mesmo   193  48  0.157405  0.075554
# 48     segundo   188  49  0.153327  0.075130
# 49    mulheres   185  50  0.150880  0.075440

# %% [markdown]
# ### Questão 3:

# %%
rslp_stemmer = RSLPStemmer()

hash_map = {}
for t in tokens:
    rad = rslp_stemmer.stem(t)
    if rad not in hash_map.keys():
        hash_map[rad] = [t]
    else:
        if t not in hash_map[rad]:
            hash_map[rad].append(t)
hash_map
# Out:
# {'continu': ['continua',
#   'continuar',
#   'continuaremos',
#   'continuidade',
#   'continuou',
#   'continuam',
#   'continuamos',
#   'continuem',
#   'continuasse',
#   'continuava',
#   'continuaram',
#   'continuamente',
#   'continue',
#   'continuarmos',
#   'continuarei',
#   'continuará',
#   'continuação',
#   'continuada',
#   'continuarem',
#   'continuaria'],
#  'dand': ['dando'],
#  'que': ['que', 'queira', 'queiram', 'queens'],
#  'fal': ['falar',
#   'fala',
#   'falam',
#   'falou',
#   'falando',
#   'falamos',
#   'falava',
#   'falavam',
#   'falas',
#   'falido',
#   'falado',
#   'falos',
#   'fale',
#   'falaram',
#   'falência',
#   'falo',
#   'falará'],
#  'atac': ['atacante',
#   'ataca',
#   'atacada',
#   'atacar',
#   'atacam',
#   'atacou',
#   'atacasse',
#   'atacantes',
#   'atacando'],
#  'itali': ['italiano', 'italianos', 'italiana'],
#  'marc': ['marcar',
#   'marcou',
#   'marcaram',
#   'marcado',
#   'marcados',
#   'marcando',
#   'marco',
#   'marca',
#   'marcação',
#   'marcos',
#   'marcia',
#   'marcas',
#   'marcava',
#   'marcada',
#   'marcantes',
#   'marcam'],
#  'do': ['dos', 'doadas', 'doado', 'doada', 'doaram'],
#  'gol': ['gols', 'gol', 'goleiro', 'goleiros', 'goleira'],
#  'vitór': ['vitória', 'vitórias'],
#  'líd': ['líder', 'líderes', 'lídia'],
#  'receb': ['recebeu',
#   'receber',
#   'recebido',
#   'recebe',
#   'recebida',
#   'recebemos',
#   'recebiam',
#   'recebia',
#   'recebi',
#   'recebem',
#   'recebidas',
#   'recebimento',
#   'receberam',
#   'receberá',
#   'receberia',
#   'receberão'],
#  'insult': ['insultos', 'insulto', 'insultam', 'insultada'],
#  'racist': ['racistas', 'racista'],
#  'comemor': ['comemorar',
#   'comemorá',
#   'comemoração',
#   'comemorativa',
#   'comemoram',
#   'comemoramos',
#   'comemoraram',
#   'comemorações',
#   'comemorado',
#   'comemorasse',
#   'comemorados',
#   'comemorarem',
#   'comemorassem',
#   'comemorando',
#   'comemorou'],
#  'frent': ['frente', 'frentes'],
#  'torc': ['torcida', 'torcedores', 'torcer', 'torcendo', 'torcedor'],
#  'adversár': ['adversária'],
#  'for': ['foram', 'fora', 'for', 'forem'],
#  'muit': ['muitas',
#   'muita',
#   'muito',
#   'muitos',
#   'muitíssimo',
#   'muitíssimas',
#   'muitíssimos'],
#  'manifest': ['manifestações',
#   'manifestou',
#   'manifestaram',
#   'manifestos',
#   'manifesto',
#   'manifestantes',
#   'manifestando',
#   'manifesta',
#   'manifestação',
#   'manifestar',
#   'manifestante',
#   'manifestem',
#   'manifestam'],
#  'apoi': ['apoio',
#   'apoiar',
#   'apoiaram',
#   'apoiado',
#   'apoiá',
#   'apoiou',
#   'apoiadores',
#   'apoiados',
#   'apoiasse',
#   'apoiador',
#   'apoiada',
#   'apoiava',
#   'apoiando'],
#  'jov': ['jovem', 'jovens'],
#  'desd': ['desde', 'desdisse'],
#  'ent': ['então', 'entendo', 'entes'],
#  'coleg': ['colegas', 'colega'],
#  'profiss': ['profissão', 'profissional', 'profissionais', 'profissões'],
#  'com': ['como',
#   'com',
#   'comer',
#   'comem',
#   'coma',
#   'comeu',
#   'comando',
#   'come',
#   'comandos',
#   'comemos',
#   'comeram',
#   'comida',
#   'comendo'],
#  'sterling': ['sterling'],
#  'yay': ['yaya'],
#  'touré': ['touré'],
#  'kevin': ['kevin'],
#  'princ': ['prince', 'princes'],
#  'boateng': ['boateng'],
#  'mari': ['mario', 'marie', 'mariana', 'mariano'],
#  'ballotell': ['ballotelli'],
#  'conden': ['condenaram',
#   'condeno',
#   'condenado',
#   'condenou',
#   'condenados',
#   'condenar',
#   'condenação',
#   'condenações',
#   'condena',
#   'condená',
#   'condenavam'],
#  'episódi': ['episódio', 'episódios'],
#  'mas': ['mas', 'masia'],
#  'entr': ['entre',
#   'entrada',
#   'entrar',
#   'entramos',
#   'entrou',
#   'entrava',
#   'entra',
#   'entraram',
#   'entradas',
#   'entro',
#   'entrasse',
#   'entrando',
#   'entrará',
#   'entraríamos',
#   'entrado',
#   'entraria',
#   'entrei',
#   'entrarem',
#   'entrarão',
#   'entravam',
#   'entram'],
#  'tod': ['todas', 'todo', 'todos', 'toda', 'todi'],
#  'express': ['expressões',
#   'expressar',
#   'expressou',
#   'expressa',
#   'expressão',
#   'expressiva',
#   'expressividade',
#   'expresso',
#   'expressivos',
#   'expressavam',
#   'expressam',
#   'expressivo',
#   'expressamente'],
#  'destac': ['destaca',
#   'destacam',
#   'destacava',
#   'destacou',
#   'destacaram',
#   'destacado',
#   'destacar',
#   'destacados',
#   'destacando',
#   'destacamento'],
#  'por': ['por', 'porão', 'porões', 'porosas'],
#  'sua': ['sua', 'suas'],
#  'contund': ['contundência', 'contundente'],
#  'jog': ['jogador',
#   'jogo',
#   'jogadores',
#   'jogará',
#   'jogos',
#   'jogada',
#   'jogam',
#   'joga',
#   'jogando',
#   'jogaram',
#   'jogar',
#   'jogado',
#   'jogados',
#   'jogou',
#   'jogadora',
#   'jogamos',
#   'jogadoras',
#   'jogaremos',
#   'jogasse',
#   'jogadas'],
#  'franc': ['francês',
#   'francesa',
#   'frances',
#   'francamente',
#   'franco',
#   'franca',
#   'francesas',
#   'france'],
#  'lilian': ['lilian'],
#  'thur': ['thuram'],
#  'ano': ['anos', 'ano'],
#  'jorn': ['jornal', 'jornais', 'jornada', 'jornadas', 'jornalismo'],
#  'mostr': ['mostrou',
#   'mostram',
#   'mostrar',
#   'mostra',
#   'mostrava',
#   'mostrado',
#   'mostrando',
#   'mostrá',
#   'mostraram',
#   'mostrada',
#   'mostrará',
#   'mostravam',
#   'mostras',
#   'mostrasse'],
#  'reje': ['rejeição'],
#  'pel': ['pelo', 'pela', 'pele', 'pelas', 'pelos'],
#  'critic': ['criticou',
#   'criticaram',
#   'criticado',
#   'criticar',
#   'criticava',
#   'criticam',
#   'criticadas'],
#  'dur': ['duramente',
#   'durante',
#   'durou',
#   'dura',
#   'durará',
#   'durão',
#   'duros',
#   'durões',
#   'dureza',
#   'duração',
#   'duro',
#   'duras',
#   'durar',
#   'durado'],
#  'defen': ['defensor', 'defensores'],
#  'leonard': ['leonardo'],
#  'bonucc': ['bonucci'],
#  'falt': ['falta',
#   'faltando',
#   'faltar',
#   'faltavam',
#   'faltarão',
#   'faltam',
#   'faltaram',
#   'faltou',
#   'faltava'],
#  'fibr': ['fibra'],
#  'cas': ['caso',
#   'casos',
#   'casa',
#   'casamento',
#   'casual',
#   'casar',
#   'casou',
#   'casas',
#   'casado',
#   'casada',
#   'casados',
#   'casinhas',
#   'case',
#   'casinha',
#   'casualmente',
#   'casaram'],
#  'divid': ['dividir',
#   'dividiu',
#   'divide',
#   'dividido',
#   'dividiam',
#   'dividem',
#   'dividendo',
#   'dividendos'],
#  'culp': ['culpa', 'culposo', 'culpadas', 'culpar', 'culpados', 'culpada'],
#  'própri': ['próprio', 'próprios'],
#  'kean': ['kean', 'keane'],
#  'após': ['após'],
#  'ach': ['acho',
#   'acha',
#   'achou',
#   'achava',
#   'achavam',
#   'achar',
#   'achado',
#   'acharam',
#   'acham',
#   'achem',
#   'achando',
#   'achei',
#   'achados'],
#  'ele': ['ele', 'eles', 'eleições', 'eleição'],
#  'tem': ['tem',
#   'tema',
#   'temos',
#   'teme',
#   'temor',
#   'temas',
#   'temiam',
#   'temo',
#   'temer',
#   'temida',
#   'temem',
#   'temia',
#   'temendo',
#   'temido'],
#  'porqu': ['porque', 'porquê'],
#  'mois': ['moise'],
#  'não': ['não'],
#  'dev': ['deveria',
#   'deve',
#   'devem',
#   'dever',
#   'deverá',
#   'devido',
#   'devia',
#   'deveriam',
#   'devemos',
#   'deviam',
#   'deverão',
#   'devidos',
#   'devo',
#   'deveríamos',
#   'devam',
#   'deva',
#   'devidas',
#   'deveres',
#   'deveras',
#   'devida',
#   'deveremos',
#   'deveram'],
#  'di': ['diante', 'diariamente', 'diaria'],
#  'diss': ['disse', 'disso', 'disseram', 'dissessem'],
#  'zagu': ['zagueiro', 'zagueiros'],
#  'diz': ['diz',
#   'dizer',
#   'dizem',
#   'dizia',
#   'dizê',
#   'dizendo',
#   'diziam',
#   'dizemos',
#   'dizeres'],
#  'basic': ['basicamente'],
#  'gent': ['gente'],
#  'pens': ['pensa',
#   'pensar',
#   'pensão',
#   'pensem',
#   'pensam',
#   'pensamento',
#   'pensamos',
#   'pensava',
#   'pensou',
#   'pensados',
#   'pensamentos',
#   'pensaria',
#   'pensei',
#   'pensativo',
#   'pense',
#   'pensasse',
#   'penso',
#   'pensando',
#   'pensões',
#   'pensaram',
#   'pensada',
#   'pensador',
#   'pensado',
#   'pensavam',
#   'pensarem'],
#  'pergunt': ['pergunta',
#   'perguntar',
#   'perguntaram',
#   'perguntas',
#   'perguntavam',
#   'perguntando',
#   'pergunto',
#   'perguntam',
#   'perguntava',
#   'perguntado',
#   'perguntou',
#   'pergunte',
#   'perguntados'],
#  'corret': ['correta', 'correto', 'corretamente'],
#  'par': ['para',
#   'parada',
#   'par',
#   'pararam',
#   'parido',
#   'parei',
#   'parar',
#   'param',
#   'parou',
#   'paria',
#   'pare',
#   'paramos',
#   'pares',
#   'parassem',
#   'pará',
#   'parir',
#   'parem',
#   'parando',
#   'parado'],
#  'ser': ['seria',
#   'seriam',
#   'será',
#   'ser',
#   'serão',
#   'serem',
#   'seres',
#   'seriamente',
#   'seremos',
#   'serial',
#   'seríamos'],
#  'fez': ['fez'],
#  'merec': ['merecer',
#   'merece',
#   'merecidos',
#   'merecia',
#   'merecem',
#   'merecemos'],
#  'tant': ['tanto', 'tantas', 'tanta', 'tantos'],
#  'desprez': ['desprezo', 'desprezava'],
#  '[bonucci]': ['[bonucci]'],
#  'est': ['estão',
#   'estava',
#   'está',
#   'estado',
#   'estávamos',
#   'este',
#   'estamos',
#   'estados',
#   'estar',
#   'estarmos',
#   'esta',
#   'estes',
#   'ester',
#   'estavam',
#   'estou',
#   'estante',
#   'estada',
#   'estaria',
#   'estável',
#   'estando',
#   'estas',
#   'estariam',
#   'estaremos',
#   'estima',
#   'estará',
#   'estáveis',
#   'esteira',
#   'estarei'],
#  'err': ['errados', 'errou', 'erros', 'errado', 'erro', 'erra', 'errada'],
#  'foi': ['foi'],
#  'provoc': ['provocando',
#   'provocou',
#   'provoca',
#   'provocava',
#   'provocada',
#   'provocativo',
#   'provocará',
#   'provocar',
#   'provocação',
#   'provocado',
#   'provocaram',
#   'provocações',
#   'provocados'],
#  'reaç': ['reação', 'reações'],
#  'tão': ['tão'],
#  'violent': ['violenta',
#   'violentos',
#   'violento',
#   'violentado',
#   'violentadas',
#   'violentas'],
#  'quant': ['quanto',
#   'quantias',
#   'quantia',
#   'quantas',
#   'quantidade',
#   'quantos'],
#  'acontec': ['acontece',
#   'acontecerá',
#   'aconteceu',
#   'acontecido',
#   'acontecia',
#   'acontecimentos',
#   'acontecer',
#   'acontecimento',
#   'aconteceram',
#   'acontecendo',
#   'aconteceria'],
#  'qu': ['quando', 'quem', 'quer', 'queríamos', 'quai'],
#  'caus': ['causa',
#   'causas',
#   'causou',
#   'causar',
#   'causaria',
#   'causaram',
#   'causando',
#   'causadores',
#   'causada',
#   'causado'],
#  'dess': ['dessas', 'desse', 'dessa', 'desses', 'dessem'],
#  'pesso': ['pessoas', 'pessoa', 'pessoano'],
#  'cois': ['coisas', 'coisa'],
#  'vão': ['vão'],
#  'filh': ['filho', 'filhos', 'filha', 'filhas'],
#  'imigr': ['imigrantes', 'imigração'],
#  'cost': ['costa', 'costas', 'costinha'],
#  'marfim': ['marfim'],
#  'suport': ['suportou',
#   'suportaram',
#   'suportes',
#   'suportar',
#   'suportava',
#   'suporte'],
#  'cant': ['cantos', 'cantaram', 'cantando', 'cantar', 'cantou', 'canto'],
#  'proced': ['procedentes',
#   'procedia',
#   'procedimento',
#   'procedente',
#   'procedimentos',
#   'procede'],
#  'curv': ['curva', 'curvas', 'curvar'],
#  'nort': ['norte'],
#  'ond': ['onde', 'ondas', 'onda'],
#  'fic': ['ficam',
#   'ficar',
#   'ficou',
#   'ficaram',
#   'ficava',
#   'fica',
#   'fico',
#   'ficaria',
#   'ficado',
#   'ficaríamos',
#   'ficará',
#   'ficando',
#   'ficariam',
#   'ficarem',
#   'ficarão',
#   'ficavam',
#   'ficasse'],
#  'extrem': ['extremistas',
#   'extrema',
#   'extremismos',
#   'extremamente',
#   'extremismo',
#   'extremidades',
#   'extremas'],
#  'cagliar': ['cagliari'],
#  'decid': ['decidiu',
#   'decidido',
#   'decidir',
#   'decide',
#   'decidissem',
#   'decidi',
#   'decididas',
#   'decidiram',
#   'decidimos',
#   'decidida',
#   'decidiria',
#   'decidia',
#   'decididos',
#   'decida'],
#  'juv': ['juve'],
#  'ret': ['reta', 'retidas', 'retire', 'retos', 'retira', 'retiram'],
#  'final': ['final',
#   'finais',
#   'finalização',
#   'finalmente',
#   'finalizar',
#   'finalizadas',
#   'finalistas'],
#  'part': ['partida',
#   'partir',
#   'parte',
#   'partido',
#   'partidos',
#   'partes',
#   'parta',
#   'partem',
#   'partiu',
#   'parto',
#   'partindo',
#   'partidas'],
#  'posicion': ['posicionou', 'posicionado', 'posicionem', 'posicionamento'],
#  'braç': ['braços', 'braço'],
#  'cruz': ['cruz',
#   'cruzamento',
#   'cruzadas',
#   'cruzou',
#   'cruzar',
#   'cruzaram',
#   'cruzam',
#   'cruzamentos',
#   'cruzados',
#   'cruzada',
#   'cruzado',
#   'cruzeiro'],
#  'num': ['numa', 'num'],
#  'atitud': ['atitude', 'atitudes'],
#  'desafi': ['desafiadora', 'desafios', 'desafiaram', 'desafio'],
#  'cole': ['coletiva', 'coletivos', 'coletivo', 'coletivas'],
#  'seu': ['seu', 'seus'],
#  'gest': ['gesto',
#   'gestão',
#   'gestos',
#   'gestões',
#   'gestação',
#   'gestando',
#   'gestantes'],
#  'houv': ['houve', 'houver', 'houvesse'],
#  'depois': ['depois'],
#  'cont': ['conter',
#   'contarão',
#   'conta',
#   'contando',
#   'contida',
#   'contas',
#   'contam',
#   'conto',
#   'contou',
#   'contar',
#   'contado',
#   'contaria',
#   'contaram',
#   'contava',
#   'contadas',
#   'contará',
#   'contê',
#   'contagem',
#   'contem',
#   'contá',
#   'contemos',
#   'contido',
#   'contente',
#   'contada'],
#  'mais': ['mais'],
#  'tim': ['time', 'tim', 'times'],
#  'dar': ['dar', 'daria', 'daremos', 'dará'],
#  'exempl': ['exemplo', 'exemplar', 'exemplares', 'exemplos'],
#  'ao': ['aos'],
#  'faz': ['fazer',
#   'fazem',
#   'fazendo',
#   'faz',
#   'fazê',
#   'faziam',
#   'fazia',
#   'fazerem',
#   'fazemos',
#   'fazíamos'],
#  'ess': ['essas', 'esse', 'essa', 'esses', 'essências', 'essência'],
#  'quil': ['quis', 'quilos'],
#  'suaviz': ['suavizar', 'suavizavam', 'suavizou'],
#  'declar': ['declarações',
#   'declarou',
#   'declarado',
#   'declarasse',
#   'declaração',
#   'declaravam',
#   'declarada',
#   'declarar',
#   'declararam'],
#  'hor': ['horas', 'horário', 'hora', 'horários'],
#  'quer': ['quero',
#   'querem',
#   'queriam',
#   'queria',
#   'querido',
#   'queridos',
#   'querer',
#   'queremos',
#   'querendo'],
#  'esclarec': ['esclarecer',
#   'esclarecimentos',
#   'esclarecimento',
#   'esclarece',
#   'esclarecida',
#   'esclarecido',
#   'esclarecidas',
#   'esclareceu'],
#  'meu': ['meus', 'meu'],
#  'sent': ['sentimentos',
#   'sentirei',
#   'sente',
#   'sentados',
#   'sentiu',
#   'sentido',
#   'senti',
#   'sentar',
#   'sentava',
#   'sentado',
#   'sentei',
#   'sentimento',
#   'sentimos',
#   'sentia',
#   'sentiram',
#   'sentem',
#   'sentam',
#   'sentir',
#   'sentada',
#   'sentirem',
#   'sentisse',
#   'sentíamos',
#   'sentou',
#   'sentindo',
#   'sentidos'],
#  'ont': ['ontem'],
#  'entrevist': ['entrevistaram',
#   'entrevistador',
#   'entrevistou',
#   'entrevistei',
#   'entrevistados',
#   'entrevistar',
#   'entrevistá',
#   'entrevistamos',
#   'entrevistada'],
#  'minh': ['minhas', 'minha'],
#  'palavr': ['palavras', 'palavra'],
#  'cl': ['claramente', 'claras', 'classe', 'clara', 'classes'],
#  'mal': ['mal', 'mali', 'malas', 'mala'],
#  'interpret': ['interpretadas',
#   'interpreta',
#   'interpretados',
#   'interpretando',
#   'interpretar',
#   'interpretação',
#   'interpretado',
#   'interpretações',
#   'interpretá',
#   'interpretada',
#   'interpretou'],
#  'prova': ['provavelmente'],
#  'apress': ['apressei', 'apressasse', 'apressaram', 'apressou'],
#  'form': ['forma',
#   'formas',
#   'formação',
#   'formada',
#   'formado',
#   'formam',
#   'formar',
#   'formadas',
#   'formou',
#   'formações',
#   'formos',
#   'formarão',
#   'formador',
#   'formadores'],
#  'sufici': ['suficientes', 'suficiente', 'suficientemente'],
#  'sobr': ['sobre',
#   'sobrou',
#   'sobrinha',
#   'sobrinho',
#   'sobram',
#   'sobrará',
#   'sobrinhas',
#   'sobrinhos'],
#  'rac': ['racismo', 'raciais', 'racial'],
#  'discrimin': ['discriminação', 'discriminadas', 'discriminam'],
#  'cert': ['certas',
#   'certeza',
#   'certa',
#   'certo',
#   'certamente',
#   'certos',
#   'certidão',
#   'certezas'],
#  'são': ['são', 'sãos'],
#  'sempr': ['sempre'],
#  'injustific': ['injustificáveis'],
#  'pod': ['pode',
#   'poderiam',
#   'podendo',
#   'podem',
#   'podando',
#   'poder',
#   'poderão',
#   'podemos',
#   'poderia',
#   'podia',
#   'poderá',
#   'podiam',
#   'poderíamos',
#   'poderes',
#   'podíamos',
#   'podido',
#   'poderem',
#   'poderemos'],
#  'hav': ['haver',
#   'havia',
#   'haviam',
#   'haveria',
#   'have',
#   'havendo',
#   'haverá',
#   'havíamos'],
#  'entend': ['entendidos',
#   'entendido',
#   'entender',
#   'entendê',
#   'entende',
#   'entendemos',
#   'entendem',
#   'entendessem',
#   'entendia',
#   'entendi',
#   'entenda',
#   'entendida',
#   'entendeu',
#   'entendimento',
#   'entenderam'],
#  'iss': ['isso'],
#  'retific': ['retificação'],
#  'coment': ['comentários',
#   'comentam',
#   'comenta',
#   'comentou',
#   'comentada',
#   'comentado',
#   'comentário',
#   'comentar',
#   'comentem',
#   'comentava',
#   'comentados',
#   'comentadas'],
#  'vergonh': ['vergonhosos', 'vergonha'],
#  'vai': ['vaias', 'vai', 'vaiar'],
#  'represent': ['representam',
#   'representante',
#   'representaram',
#   'representar',
#   'representado',
#   'representativas',
#   'representados',
#   'representativa',
#   'representa',
#   'representação',
#   'representando',
#   'representarão',
#   'representava',
#   'representada',
#   'representantes',
#   'representativo',
#   'representações',
#   'representavam',
#   'representassem',
#   'representou'],
#  'inclu': ['incluindo',
#   'incluída',
#   'incluído',
#   'inclui',
#   'incluem',
#   'incluídas',
#   'incluíram',
#   'incluir',
#   'incluam',
#   'incluiu',
#   'incluídos'],
#  'crianç': ['crianças', 'criança'],
#  'têm': ['têm'],
#  'cor': ['cor', 'cores', 'coro', 'coros', 'corão'],
#  'também': ['também'],
#  'parabeniz': ['parabenizou', 'parabenizaram'],
#  'bem': ['bem', 'bens'],
#  'mant': ['manter',
#   'mantida',
#   'mantinha',
#   'manteria',
#   'mantendo',
#   'mantidos',
#   'mantidas',
#   'mantido',
#   'manterá'],
#  'orgulh': ['orgulho', 'orgulhava', 'orgulham', 'orgulhoso'],
#  'retid': ['retidão'],
#  'advers': ['adversidade',
#   'adversário',
#   'adversários',
#   'adversativo',
#   'adversa',
#   'adverso',
#   'adversas'],
#  'conv': ['convido', 'convida'],
#  'negr': ['negras', 'negro', 'negra', 'negros', 'negrão'],
#  'mesm': ['mesmo', 'mesma', 'mesmos', 'mesmas'],
#  'exig': ['exigir',
#   'exigem',
#   'exigindo',
#   'exigiram',
#   'exigida',
#   'exigidos',
#   'exigia',
#   'exige',
#   'exigiu',
#   'exigido',
#   'exigência',
#   'exigente',
#   'exigências'],
#  'respeit': ['respeito',
#   'respeitando',
#   'respeite',
#   'respeitado',
#   'respeitem',
#   'respeitados',
#   'respeitosa',
#   'respeitam',
#   'respeita',
#   'respeitou'],
#  'pi': ['pior', 'pis', 'piada', 'piores', 'piadas'],
#  'ela': ['elas', 'ela'],
#  'últ': ['último', 'últimas', 'últimos', 'última'],
#  'papel': ['papel', 'papeis', 'papéis'],
#  'da': ['das'],
#  'institu': ['instituições',
#   'instituição',
#   'instituído',
#   'instituída',
#   'instituir'],
#  'no': ['nos'],
#  'árbitr': ['árbitro', 'árbitros'],
#  'interromp': ['interrompeu',
#   'interrompido',
#   'interrompem',
#   'interromper',
#   'interrompidas',
#   'interrompendo'],
#  'alg': ['algo'],
#  'feit': ['feito', 'feitas', 'feitos', 'feita', 'feitosa'],
#  'real': ['realidade',
#   'realmente',
#   'real',
#   'reais',
#   'realismo',
#   'realistas',
#   'realidades',
#   'realista'],
#  'autoridad': ['autoridades', 'autoridade'],
#  'futebol': ['futebol', 'futeboleira'],
#  'import': ['importam',
#   'importância',
#   'importante',
#   'importantes',
#   'importa',
#   'importação',
#   'importações'],
#  'incomod': ['incomodassem',
#   'incomoda',
#   'incomodados',
#   'incomodam',
#   'incomodasse',
#   'incomodava',
#   'incomodado'],
#  'ter': ['teria',
#   'teríamos',
#   'ter',
#   'terá',
#   'terão',
#   'teremos',
#   'terem',
#   'teriam',
#   'tereza'],
#  'deix': ['deixado',
#   'deixou',
#   'deixaram',
#   'deixando',
#   'deixadas',
#   'deixar',
#   'deixa',
#   'deixem',
#   'deixava',
#   'deixei',
#   'deixaria',
#   'deixamos',
#   'deixará',
#   'deixemos',
#   'deixada',
#   'deixá',
#   'deixam',
#   'deixe',
#   'deixados',
#   'deixarem'],
#  'camp': ['campo', 'camp', 'campos'],
#  'encontr': ['encontrado',
#   'encontro',
#   'encontramos',
#   'encontrarão',
#   'encontra',
#   'encontrados',
#   'encontrou',
#   'encontrar',
#   'encontram',
#   'encontros',
#   'encontradas',
#   'encontrará',
#   'encontrada',
#   'encontraram',
#   'encontravam',
#   'encontre'],
#  'uma': ['uma', 'umas'],
#  'soluç': ['solução', 'soluções', 'soluça'],
#  'conclu': ['concluiu',
#   'concluem',
#   'concluída',
#   'conclui',
#   'concluindo',
#   'concluir'],
#  'enfrent': ['enfrentam',
#   'enfrentariam',
#   'enfrentar',
#   'enfrentamentos',
#   'enfrentado',
#   'enfrentarão',
#   'enfrentamento',
#   'enfrenta',
#   'enfrentava',
#   'enfrentou',
#   'enfrentando',
#   'enfrentará',
#   'enfrentamos',
#   'enfrentaram',
#   'enfrentados',
#   'enfrento'],
#  'nest': ['nesta', 'neste', 'nestes', 'nestas'],
#  'quart': ['quarta', 'quartas', 'quarto', 'quartos'],
#  'feir': ['feira', 'feiras'],
#  '17h': ['17h'],
#  'brasíl': ['brasília'],
#  'oit': ['oitavas', 'oito', 'oit'],
#  'transmit': ['transmitida',
#   'transmitir',
#   'transmitido',
#   'transmitia',
#   'transmite',
#   'transmitidos'],
#  'págin': ['página', 'páginas'],
#  'esport': ['esporte', 'esportes', 'esportista', 'esportistas'],
#  'inter': ['interativo',
#   'interesse',
#   'interativa',
#   'interesses',
#   'interativas',
#   'interativos',
#   'interagem',
#   'interações'],
#  'facebook': ['facebook'],
#  'paril': ['paris'],
#  'traz': ['traz', 'trazem', 'trazer', 'trazê', 'traziam', 'trazia'],
#  'ótim': ['ótima', 'ótimo'],
#  'vantag': ['vantagem', 'vantagens'],
#  'ida': ['ida', 'idas'],
#  'inglaterr': ['inglaterra'],
#  'dua': ['duas'],
#  'assist': ['assistências',
#   'assistiu',
#   'assistirem',
#   'assistir',
#   'assistindo',
#   'assistente',
#   'assistiam',
#   'assistia',
#   'assistencial',
#   'assistenciais',
#   'assistência',
#   'assistida',
#   'assistimos',
#   'assistido',
#   'assistiria',
#   'assistem',
#   'assistiram'],
#  'mar': ['maria', 'mar', 'mares', 'marinha', 'marinho'],
#  'kimpemb': ['kimpembe'],
#  'mbappé': ['mbappé'],
#  'fiz': ['fizeram',
#   'fiz',
#   'fizessem',
#   'fizesse',
#   'fizemos',
#   'fizerem',
#   'fizermos',
#   'fizer'],
#  'frances': ['franceses'],
#  'aind': ['ainda'],
#  'volt': ['volta',
#   'voltou',
#   'voltaram',
#   'volte',
#   'voltando',
#   'voltar',
#   'voltamos',
#   'voltaria',
#   'volto',
#   'voltará',
#   'voltem',
#   'voltam',
#   'voltarão',
#   'voltei',
#   'voltarmos',
#   'voltaste',
#   'voltas',
#   'voltava',
#   'voltadas',
#   'voltada',
#   'voltarei',
#   'voltados'],
#  'united': ['united'],
#  'sem': ['sem', 'semi'],
#  'melhor': ['melhor',
#   'melhores',
#   'melhorar',
#   'melhorem',
#   'melhorou',
#   'melhoraram',
#   'melhoras',
#   'melhora',
#   'melhorando'],
#  'pogb': ['pogba'],
#  'suspens': ['suspenso', 'suspensão', 'suspensas', 'suspensões', 'suspensos'],
#  'cart': ['cartão',
#   'carta',
#   'cartas',
#   'carter',
#   'carteira',
#   'cartões',
#   'carteiras'],
#  'vermelh': ['vermelho', 'vermelha'],
#  'venc': ['venceu',
#   'vencer',
#   'vencedor',
#   'vencê',
#   'vencimentos',
#   'vencedoras',
#   'vencidas',
#   'vencedora',
#   'vencido'],
#  'consegu': ['conseguiu',
#   'conseguir',
#   'conseguiram',
#   'conseguido',
#   'conseguindo',
#   'conseguia',
#   'consegui',
#   'conseguiam',
#   'conseguimos'],
#  'classific': ['classificação',
#   'classificou',
#   'classificar',
#   'classificaria',
#   'classificaram',
#   'classificados',
#   'classificada',
#   'classificando',
#   'classificado'],
#  'épic': ['épica', 'épicos'],
#  'ingles': ['ingleses'],
#  'vir': ['viram',
#   'virando',
#   'vir',
#   'virar',
#   'virou',
#   'virada',
#   'viriam',
#   'virado',
#   'virei',
#   'virarem',
#   'viraram',
#   'vira',
#   'virá',
#   'viria'],
#  'bernat': ['bernat'],
#  'empat': ['empatar', 'empatou', 'empate', 'empatia'],
#  'ant': ['antes', 'anti', 'ante'],
#  'lukaku': ['lukaku'],
#  'nov': ['novamente', 'nove', 'nova', 'novos', 'novo', 'novas', 'novíssima'],
#  'pênalt': ['pênalti'],
#  'ajud': ['ajuda',
#   'ajudem',
#   'ajudar',
#   'ajudas',
#   'ajudasse',
#   'ajudaram',
#   'ajudou',
#   'ajudam',
#   'ajudá',
#   'ajudarmos',
#   'ajude',
#   'ajudarem',
#   'ajudados',
#   'ajudaria',
#   'ajudante',
#   'ajudado',
#   'ajudassem'],
#  'acrésc': ['acréscimos'],
#  'sel': ['selarem', 'selou', 'selo', 'selos', 'selada'],
#  'elimin': ['eliminação',
#   'eliminado',
#   'eliminou',
#   'eliminar',
#   'eliminava',
#   'eliminará',
#   'elimina',
#   'eliminada'],
#  'equip': ['equipe',
#   'equipes',
#   'equipados',
#   'equipamento',
#   'equipamentos',
#   'equiparam',
#   'equipam'],
#  'domin': ['dominaram',
#   'dominante',
#   'dominar',
#   'dominadas',
#   'dominava',
#   'domina',
#   'dominando',
#   'dominado',
#   'dominam',
#   'dominada',
#   'dominavam'],
#  'poss': ['posse', 'posses', 'possa', 'possam', 'possamos', 'posso'],
#  'bol': ['bola', 'bolas', 'bolos', 'bolões', 'boles', 'bolo'],
#  'mat': ['matado',
#   'matar',
#   'mata',
#   'mato',
#   'mateus',
#   'mataram',
#   'mataria',
#   'matam',
#   'matou',
#   'matei',
#   'matá',
#   'mate',
#   'matavam',
#   'matando',
#   'matadores',
#   'matador'],
#  'confront': ['confronto',
#   'confrontos',
#   'confrontados',
#   'confrontou',
#   'confrontava',
#   'confrontar',
#   'confrontadas',
#   'confrontada'],
#  'prim': ['primeiro',
#   'primeira',
#   'prima',
#   'primeiros',
#   'primários',
#   'primeiras',
#   'primos',
#   'primário',
#   'primas'],
#  'temp': ['tempo', 'tempos', 'tempinho'],
#  'tiv': ['tiveram',
#   'tivesse',
#   'tive',
#   'tiver',
#   'tivemos',
#   'tiverem',
#   'tivessem',
#   'tivermos'],
#  'individ': ['individuais', 'individual'],
#  'defês': ['defesa'],
#  'der': ['deram'],
#  'chanc': ['chances', 'chance'],
#  'log': ['logo'],
#  'lanc': ['lance'],
#  'kehr': ['kehrer'],
#  'recu': ['recuo', 'recuar', 'recuos', 'recuou'],
#  'antecip': ['antecipou',
#   'antecipadas',
#   'antecipada',
#   'antecipar',
#   'antecipando',
#   'antecipação',
#   'antecipa',
#   'antecipam',
#   'antecipado',
#   'antecipassem'],
#  'dribl': ['driblou', 'driblando'],
#  'abr': ['abrir',
#   'abriu',
#   'abre',
#   'abrisse',
#   'abriram',
#   'abrams',
#   'abreu',
#   'abrimos',
#   'abrindo',
#   'abraão',
#   'abrantes',
#   'abririam',
#   'abrem'],
#  'plac': ['placar', 'placa'],
#  'rast': ['rasteiro'],
#  'pouc': ['poucos', 'pouco', 'pouca', 'poucas'],
#  'minut': ['minutos', 'minuto'],
#  'rashford': ['rashford'],
#  'arrisc': ['arriscou',
#   'arriscado',
#   'arriscam',
#   'arriscada',
#   'arriscar',
#   'arrisca',
#   'arriscadas'],
#  'áre': ['área', 'áreas'],
#  'buffon': ['buffon'],
#  'bat': ['bateu',
#   'batendo',
#   'batismo',
#   'bate',
#   'bater',
#   'batidas',
#   'batido',
#   'baterias'],
#  'roup': ['roupa', 'roupas'],
#  'rebot': ['rebote'],
#  'desfalc': ['desfalcado'],
#  'titul': ['titulares', 'titulada', 'titulou', 'titular'],
#  'recolh': ['recolheu', 'recolhem'],
#  'segund': ['segundo', 'segunda', 'segundos', 'segundas'],
#  'precis': ['precisando',
#   'precisa',
#   'precisava',
#   'precisou',
#   'precisamos',
#   'preciso',
#   'precisão',
#   'precisasse',
#   'precisamente',
#   'precisam',
#   'precisavam',
#   'precisariam',
#   'precisar',
#   'precisará',
#   'precisei',
#   'precise',
#   'precisarão',
#   'precisem',
#   'precisassem'],
#  'revert': ['reverter', 'revertida', 'revertido', 'revertendo'],
#  'don': ['donos', 'dono', 'donas', 'dona', 'don'],
#  'tev': ['teve'],
#  'aproveit': ['aproveitou',
#   'aproveita',
#   'aproveitado',
#   'aproveitável',
#   'aproveitaram',
#   'aproveitam'],
#  'manchest': ['manchester'],
#  'resolv': ['resolveu',
#   'resolvido',
#   'resolver',
#   'resolvida',
#   'resolve',
#   'resolveria',
#   'resolvesse',
#   'resolvam',
#   'resolvemos'],
#  'cim': ['cima'],
#  'busc': ['busca',
#   'buscam',
#   'busco',
#   'buscamos',
#   'buscado',
#   'buscadores',
#   'buscador',
#   'buscando',
#   'buscar',
#   'buscava',
#   'buscou',
#   'buscas',
#   'buscavam',
#   'buscávamos',
#   'buscá'],
#  'milagr': ['milagre', 'milagres'],
#  'cinc': ['cinco', 'cinc'],
#  'dalot': ['dalot'],
#  'chut': ['chutou', 'chute', 'chutes', 'chutando', 'chuteiras'],
#  'desvi': ['desviou', 'desviar', 'desviados', 'desvio', 'desvios', 'desviem'],
#  'dentr': ['dentro', 'dentre'],
#  'consult': ['consultar',
#   'consultou',
#   'consultoria',
#   'consultadas',
#   'consultor',
#   'consultados',
#   'consultas',
#   'consultado'],
#  'var': ['var', 'variam'],
#  'convert': ['convertido',
#   'convertendo',
#   'converter',
#   'convertem',
#   'converteu',
#   'convertidos',
#   'converteria',
#   'convertidas',
#   'convertida',
#   'converti'],
#  'thom': ['thomas'],
#  'tuchel': ['tuchel'],
#  'coloc': ['colocou',
#   'colocação',
#   'colocava',
#   'colocá',
#   'colocadas',
#   'coloca',
#   'colocaram',
#   'colocasse',
#   'colocados',
#   'colocamos',
#   'colocado',
#   'colocando',
#   'colocar',
#   'colocam',
#   'colocará',
#   'colocaria',
#   'colocarem'],
#  'recuper': ['recuperado',
#   'recuperada',
#   'recuperou',
#   'recuperação',
#   'recuperar',
#   'recuperadas',
#   'recuperados',
#   'recuperando'],
#  'les': ['lesão', 'lesa', 'lesões'],
#  'desesper': ['desespero', 'desesperado', 'desesperadas', 'desesperados'],
#  'persist': ['persistiu',
#   'persistem',
#   'persistente',
#   'persistirão',
#   'persistir'],
#  'até': ['até'],
#  'inédit': ['inédita', 'inédito', 'inéditas', 'inéditos'],
#  'nunc': ['nunca'],
#  'histór': ['história',
#   'histórico',
#   'histórias',
#   'histórica',
#   'históricas',
#   'históricos'],
#  'champiom': ['champions'],
#  'acab': ['acabou',
#   'acaba',
#   'acabaram',
#   'acabava',
#   'acabar',
#   'acabam',
#   'acabará',
#   'acabando',
#   'acabaria',
#   'acabasse',
#   'acabe',
#   'acabara',
#   'acabado',
#   'acabem',
#   'acabavam',
#   'acabarão'],
#  'vexam': ['vexame'],
#  'terc': ['terceira', 'terceiro', 'terceiros'],
#  'segu': ['seguida',
#   'seguidas',
#   'seguidores',
#   'seguiu',
#   'seguir',
#   'seguido',
#   'seguindo',
#   'seguem',
#   'seguiam',
#   'seguisse',
#   'seguidor',
#   'seguiram',
#   'seguidos',
#   'seguia',
#   'seguimos'],
#  'milion': ['milionário', 'milionários'],
#  'saint': ['saint'],
#  'germain': ['germain'],
#  'fas': ['fase', 'fases'],
#  'tornei': ['torneio', 'torneios'],
#  'europ': ['europeu', 'europa', 'europeus'],
#  'som': ['somada',
#   'soma',
#   'somos',
#   'som',
#   'somarem',
#   'somam',
#   'somaram',
#   'somarmos',
#   'somar',
#   'somando',
#   'somados',
#   'somavam',
#   'somadas',
#   'somado',
#   'somava',
#   'somou'],
#  'neym': ['neymar'],
#  'recup': ['recupera', 'recupere', 'recuperá'],
#  'direit': ['direito', 'direita', 'direitos', 'direitas', 'direitistas'],
#  'tud': ['tudo'],
#  'camarot': ['camarotes'],
#  'parc': ['parc',
#   'parcialmente',
#   'parceiras',
#   'parceria',
#   'parceiro',
#   'parceira',
#   'parceiros',
#   'parcerias',
#   'parcial'],
#  'de': ['des'],
#  'estádi': ['estádio', 'estádios'],
#  'nou': ['nou'],
#  'país': ['país', 'países'],
#  'far': ['fará', 'faria', 'farão', 'faríamos', 'faro'],
#  'cobert': ['cobertura', 'coberto'],
#  'viv': ['vivo',
#   'vivem',
#   'vive',
#   'viver',
#   'vivemos',
#   'vivia',
#   'vivido',
#   'viveu',
#   'vivida',
#   'viva',
#   'viveram',
#   'vivi',
#   'vivências',
#   'vivas',
#   'viverão',
#   'vividas',
#   'vividos',
#   'vivendo',
#   'vivos',
#   'viverá'],
#  'apes': ['apesar'],
#  'boa': ['boa', 'boas'],
#  'fek': ['fekir'],
#  'princip': ['principal', 'principalmente', 'principais'],
#  'destaqu': ['destaque', 'destaques'],
#  'lyon': ['lyon'],
#  'aus': ['ausência', 'ausências'],
#  'barç': ['barça'],
#  'únic': ['única', 'único', 'únicas', 'únicos'],
#  'dúv': ['dúvida', 'dúvidas'],
#  'dembel': ['dembele'],
#  'substitu': ['substituído',
#   'substituída',
#   'substituindo',
#   'substituíram',
#   'substituir',
#   'substituiria',
#   'substituição',
#   'substitua'],
#  'confirm': ['confirmados',
#   'confirmam',
#   'confirmaram',
#   'confirmar',
#   'confirmação',
#   'confirmado',
#   'confirmava',
#   'confirmando',
#   'confirma',
#   'confirmou',
#   'confirmada',
#   'confirme'],
#  'banc': ['banco',
#   'bancos',
#   'bancada',
#   'bancários',
#   'bancadas',
#   'banca',
#   'banqueiros',
#   'bancar',
#   'bancário'],
#  '283': ['283'],
#  'dia': ['dias', 'dia'],
#  'saíd': ['saída', 'saído', 'saídos', 'saídas'],
#  'club': ['clube', 'clubes'],
#  'mereng': ['merengue', 'merengues'],
#  'doi': ['dois', 'doi'],
#  'mei': ['meio', 'meia', 'meios'],
#  'carg': ['cargo', 'carga', 'cargos', 'cargas'],
#  'títul': ['títulos', 'título'],
#  'trê': ['três'],
#  'moment': ['momento', 'momentos'],
#  'époc': ['época', 'épocas'],
#  'decis': ['decisão', 'decisões', 'decisiva', 'decisivo', 'decisivos'],
#  'gel': ['gelados', 'gelo', 'geleira'],
#  'set': ['setores', 'sete', 'set', 'setor'],
#  'madrilenh': ['madrilenha', 'madrilenhas'],
#  'zidan': ['zidane'],
#  'retorn': ['retorna',
#   'retornando',
#   'retornar',
#   'retorno',
#   'retornaram',
#   'retornou',
#   'retornam'],
#  'grav': ['grave',
#   'gravemente',
#   'gravador',
#   'gravura',
#   'gravações',
#   'gravuras',
#   'gravação',
#   'gravo',
#   'gravadoras',
#   'gravou',
#   'gravar',
#   'gravadora',
#   'gravá',
#   'gravada',
#   'graves',
#   'gravidade',
#   'gravados',
#   'gravamos'],
#  'cris': ['crise', 'crises'],
#  'espor': ['esportiva', 'esportivas', 'esportivo', 'esportivos'],
#  'desencade': ['desencadeada',
#   'desencadearam',
#   'desencadeadas',
#   'desencadeia'],
#  'perd': ['perder',
#   'perdendo',
#   'perderam',
#   'perdido',
#   'perda',
#   'perdidos',
#   'perdeu',
#   'perdedores',
#   'perde',
#   'perdesse',
#   'perdia',
#   'perdi',
#   'perderia',
#   'perdão',
#   'perderemos',
#   'perdê',
#   'perdidas',
#   'perdas',
#   'perdem',
#   'perdemos'],
#  'apen': ['apenas'],
#  'seman': ['semana',
#   'semanas',
#   'semanais',
#   'semanário',
#   'semanalmente',
#   'semanal'],
#  'disput': ['disputa',
#   'disputou',
#   'disputar',
#   'disputas',
#   'disputado',
#   'disputavam',
#   'disputando',
#   'disputados',
#   'disputaram',
#   'disputarão'],
#  'trein': ['treinador',
#   'treinamento',
#   'treinados',
#   'treinado',
#   'treinam',
#   'treinamentos',
#   'treina',
#   'treino',
#   'treinar',
#   'treinadora',
#   'treinando',
#   'treinadores',
#   'treinada'],
#  'tempor': ['temporada',
#   'temporariamente',
#   'temporadas',
#   'temporários',
#   'temporário'],
#  'basc': ['basco'],
#  'demit': ['demitido', 'demitidas', 'demitiu', 'demitida'],
#  'seleç': ['seleção', 'seleções'],
#  'nacion': ['nacional',
#   'nacionais',
#   'nacionalmente',
#   'nacionalismo',
#   'nacionalizado',
#   'nacionalização',
#   'nacionalista',
#   'nacionalistas'],
#  'anunci': ['anunciou',
#   'anunciada',
#   'anunciado',
#   'anunciar',
#   'anunciadas',
#   'anunciei',
#   'anunciando'],
#  'acord': ['acordo',
#   'acordos',
#   'acordes',
#   'acordada',
#   'acordou',
#   'acordar',
#   'acordado',
#   'acordem',
#   'acordados'],
#  'madrid': ['madrid', 'madridistas', 'madridista'],
#  'permanec': ['permaneceu',
#   'permanecer',
#   'permanecia',
#   'permanecesse',
#   'permanece',
#   'permaneceram',
#   'permanecem',
#   'permanecerão'],
#  'outubr': ['outubro'],
#  'gole': ['goleada', 'goleou', 'goleador'],
#  'result': ['resultado',
#   'resultados',
#   'resultando',
#   'resultante',
#   'resultou',
#   'resultaram',
#   'resulta'],
#  'pont': ['pontos', 'ponto', 'ponte', 'ponta', 'pontaria', 'pontes', 'pontas'],
#  'atrás': ['atrás'],
#  'lug': ['lugar', 'lugares'],
#  'vei': ['veio'],
#  'santiag': ['santiago'],
#  'solar': ['solari'],
#  'técn': ['técnico', 'técnicas', 'técnica', 'técnicos'],
#  'castill': ['castilla'],
#  'argentin': ['argentino', 'argentina', 'argentinos', 'argentinas'],
#  'turn': ['turno', 'turnê', 'turnês', 'turnos'],
#  'int': ['inteiro', 'inteira', 'into', 'inteiros', 'inter'],
#  'lig': ['liga',
#   'ligado',
#   'ligada',
#   'ligação',
#   'ligadas',
#   'ligou',
#   'ligava',
#   'ligações',
#   'ligados',
#   'ligando',
#   'ligeiro',
#   'ligeiras',
#   'ligar',
#   'ligamentos'],
#  'períod': ['período', 'períodos'],
#  'endireit': ['endireitou'],
#  'rum': ['rumo', 'rumores', 'rumamos', 'rumos'],
#  'natal': ['natal', 'natalia', 'natalidade'],
#  'estimul': ['estimulada',
#   'estimulem',
#   'estimulado',
#   'estimulou',
#   'estimular',
#   'estimulante'],
#  'entant': ['entanto'],
#  'semif': ['semifinais', 'semifinal'],
#  'cop': ['copa', 'copinho', 'copinha', 'copas'],
#  'rei': ['rei', 'reitor', 'reias'],
#  'contr': ['contra',
#   'contrário',
#   'contração',
#   'contreras',
#   'contrários',
#   'contraste',
#   'contrações',
#   'contraria'],
#  'barcel': ['barcelona'],
#  'cláss': ['clássico', 'clássicos'],
#  'sér': ['séria', 'sérias'],
#  'adeu': ['adeus'],
#  'ninguém': ['ninguém'],
#  'suspeit': ['suspeitava',
#   'suspeita',
#   'suspeitas',
#   'suspeitos',
#   'suspeito',
#   'suspeitou'],
#  'iri': ['iria', 'iriam'],
#  'emb': ['embora'],
#  'menos': ['menos'],
#  'kiev': ['kiev'],
#  'recent': ['recente', 'recentemente', 'recentes'],
#  'cheg': ['chegara',
#   'chega',
#   'chegou',
#   'chegam',
#   'chegando',
#   'chegar',
#   'chegada',
#   'chegados',
#   'chegaram',
#   'chegassem',
#   'chegaria',
#   'chegarem',
#   'chegavam',
#   'chegará',
#   'chegamos',
#   'cheguei',
#   'chegarão',
#   'chego',
#   'chegado',
#   'chegava',
#   'chegue',
#   'chegariam'],
#  'jan': ['janeiro', 'jane', 'jana'],
#  '2016': ['2016'],
#  'tinh': ['tinha', 'tinham'],
#  'sair': ['sair', 'sairia', 'sairá'],
#  'assim': ['assim'],
#  'comunic': ['comunicou',
#   'comunicado',
#   'comunicação',
#   'comunicando',
#   'comunicados',
#   'comunicações',
#   'comunicantes',
#   'comunicada',
#   'comunicar'],
#  'florentin': ['florentino'],
#  'perez': ['perez'],
#  'agor': ['agora'],
#  'sim': ['sim', 'simona', 'simão'],
#  'mes': ['meses', 'mesa'],
#  'era': ['era'],
#  'argument': ['argumentou',
#   'argumentos',
#   'argumenta',
#   'argumento',
#   'argumentando',
#   'argumentar',
#   'argumentativa',
#   'argumentamos',
#   'argumentam'],
#  'ganh': ['ganhando',
#   'ganhador',
#   'ganhou',
#   'ganhar',
#   'ganhara',
#   'ganhava',
#   'ganham',
#   'ganhadora',
#   'ganhado',
#   'ganha',
#   'ganhos',
#   'ganharam',
#   'ganhavam',
#   'ganhasse',
#   'ganhadoras',
#   'ganho',
#   'ganhe',
#   'ganhá'],
#  'mudanç': ['mudança', 'mudanças'],
#  'hoj': ['hoje'],
#  'compet': ['competições',
#   'competição',
#   'competiu',
#   'competência',
#   'competem',
#   'competente',
#   'competir',
#   'competimos'],
#  'premat': ['prematuramente'],
#  'explic': ['explicar',
#   'explicam',
#   'explica',
#   'explicação',
#   'explicarei',
#   'explicou',
#   'explicava',
#   'explicando',
#   'explicações',
#   'explico'],
#  'mud': ['mudar',
#   'mudou',
#   'mudando',
#   'mudaram',
#   'mudado',
#   'muda',
#   'mudem',
#   'mudá',
#   'mudará',
#   'mudasse',
#   'mudarem',
#   'mude'],
#  'ide': ['ideia', 'ideias'],
#  'relaç': ['relação', 'relações'],
#  'pass': ['passada',
#   'passado',
#   'passagem',
#   'passou',
#   'passando',
#   'passe',
#   'passam',
#   'passar',
#   'passaram',
#   'passa',
#   'passo',
#   'passear',
#   'passos',
#   'passarão',
#   'passava',
#   'passei',
#   'passavam',
#   'passará',
#   'passamos',
#   'passadas',
#   'passados',
#   'passagens',
#   'passaria',
#   'passassem',
#   'passá',
#   'passem',
#   'passes'],
#  'sou': ['sou'],
#  'odei': ['odeio'],
#  'vej': ['vejo', 'vejam', 'veja', 'vejamos'],
#  'vam': ['vamos'],
#  'bob': ['bobagens', 'bobinho', 'bob'],
#  'campeã': ['campeões', 'campeão'],
#  'ajax': ['ajax'],
#  'bast': ['bastidores',
#   'basta',
#   'bastou',
#   'bastava',
#   'bastão',
#   'bastante',
#   'basto',
#   'bastasse',
#   'bastaria',
#   'bastos',
#   'bastões'],
#  'reun': ['reuniões',
#   'reuniu',
#   'reunião',
#   'reunindo',
#   'reunir',
#   'reunimos',
#   'reunidos',
#   'reunido',
#   'reuniram'],
#  'reanim': ['reanimar', 'reanimá'],
#  'mour': ['mourinho', 'moure', 'mourão', 'moura'],
#  'er': ['eram'],
#  'nom': ['nomes', 'nome', 'nominal'],
#  'cit': ['citados',
#   'cita',
#   'citadas',
#   'citação',
#   'citar',
#   'citou',
#   'citada',
#   'citam',
#   'citado'],
#  'nem': ['nem'],
#  'dest': ['deste', 'desta', 'destes', 'destas'],
#  'doming': ['domingo', 'domingos'],
#  'zorill': ['zorilla'],
#  'evit': ['evitou',
#   'evitar',
#   'evitado',
#   'evitavam',
#   'evitável',
#   'evita',
#   'evitaria',
#   'evitando',
#   'evitada',
#   'evitáveis'],
#  'demiss': ['demissão', 'demissões'],
#  'cair': ['cair', 'cairá', 'cairia'],
#  'holandes': ['holandeses'],
#  'terç': ['terça', 'terço', 'terços'],
#  'itál': ['itália'],
#  'canal': ['canal', 'canais'],
#  'tnt': ['tnt'],
#  'fech': ['fechada',
#   'fechou',
#   'fechadas',
#   'fecham',
#   'fecha',
#   'fechavam',
#   'fechamos',
#   'fechar',
#   'fechamento',
#   'fecharemos',
#   'fechando'],
#  'rival': ['rival', 'rivais', 'rivalidades'],
#  'atlé': ['atlético'],
#  'espanh': ['espanha'],
#  'gimén': ['giménez'],
#  'godín': ['godín'],
#  'serv': ['servem',
#   'serviu',
#   'servir',
#   'serviam',
#   'servirão',
#   'servidores',
#   'servia',
#   'servidão',
#   'serviria'],
#  'alert': ['alerta',
#   'alertou',
#   'alertava',
#   'alertara',
#   'alertam',
#   'alertas',
#   'alertando'],
#  'espanhol': ['espanhóis', 'espanhola', 'espanhol', 'espanholas'],
#  'dão': ['dão'],
#  'esperanç': ['esperanças', 'esperança'],
#  'presid': ['presidente',
#   'presidência',
#   'presidenciais',
#   'presidentes',
#   'presidiu',
#   'presidir',
#   'presidencial',
#   'presidia',
#   'presidido',
#   'preside',
#   'presidida'],
#  'icôn': ['icônico', 'icônica'],
#  'cartol': ['cartola', 'cartolas'],
#  'brasil': ['brasileiro',
#   'brasil',
#   'brasileiros',
#   'brasileira',
#   'brasileiras',
#   'brasis'],
#  'morr': ['morreu',
#   'morreram',
#   'morrendo',
#   'morre',
#   'morrer',
#   'morreria',
#   'morrerem',
#   'morria',
#   'morrido',
#   'morrem'],
#  'hospit': ['hospital', 'hospitais', 'hospitalizada'],
#  'zon': ['zona', 'zonas'],
#  'oest': ['oeste'],
#  'rio': ['rio', 'rios'],
#  'dirig': ['dirigente',
#   'dirigentes',
#   'dirigida',
#   'dirigir',
#   'dirigido',
#   'dirigiu',
#   'dirigi',
#   'dirigiram',
#   'dirigidas',
#   'dirige',
#   'dirigindo'],
#  'super': ['superou',
#   'superação',
#   'superar',
#   'superando',
#   'superava',
#   'superado',
#   'superaram'],
#  'cânc': ['câncer'],
#  'bexig': ['bexiga', 'bexigas'],
#  'pulm': ['pulmão'],
#  'anteri': ['anteriores', 'anterior', 'anteriormente'],
#  'resist': ['resistiu',
#   'resistência',
#   'resistir',
#   'resistente',
#   'resistiam',
#   'resistem',
#   'resistiria',
#   'resistentes',
#   'resistências'],
#  'tumor': ['tumor'],
#  'cérebr': ['cérebro', 'cérebros'],
#  'diagnostic': ['diagnosticado', 'diagnosticar', 'diagnosticada'],
#  '2018': ['2018'],
#  'euric': ['eurico'],
#  'deu': ['deu', 'deus'],
#  'manhã': ['manhã', 'manhãs'],
#  'complic': ['complicações',
#   'complicada',
#   'complicado',
#   'complicadíssima',
#   'complicadíssimo'],
#  'trat': ['tratamento',
#   'tratado',
#   'tratavam',
#   'trata',
#   'tratam',
#   'tratada',
#   'tratasse',
#   'tratados',
#   'tratando',
#   'tratadas',
#   'tratava',
#   'tratou',
#   'tratarmos',
#   'tratá',
#   'tratos',
#   'tratemos',
#   'trataram',
#   'trato',
#   'tratar',
#   'tratativas',
#   'tratem'],
#  '13h': ['13h'],
#  'afast': ['afastado',
#   'afastar',
#   'afastamento',
#   'afastou',
#   'afastada',
#   'afastando',
#   'afastem',
#   'afastados'],
#  'polít': ['política', 'político', 'políticas', 'políticos'],
#  'vascaín': ['vascaína', 'vascaíno'],
#  'apresent': ['apresentou',
#   'apresentam',
#   'apresentar',
#   'apresentará',
#   'apresenta',
#   'apresentando',
#   'apresentação',
#   'apresentador',
#   'apresentado',
#   'apresentada',
#   'apresentava',
#   'apresentados',
#   'apresentarem',
#   'apresentavam',
#   'apresentaria',
#   'apresentaram',
#   'apresentadora',
#   'apresentações'],
#  'problem': ['problemas', 'problema'],
#  'motor': ['motora', 'motor', 'motorista', 'motores', 'motoras'],
#  'dificuldad': ['dificuldade', 'dificuldades'],
#  'apar': ['aparições', 'aparência', 'aparências', 'aparição'],
#  'públic': ['públicas', 'público', 'pública', 'públicos'],
#  'locomov': ['locomovia'],
#  'cade': ['cadeiras', 'cadeia', 'cadeira'],
#  'rod': ['rodas', 'rodada', 'rodar', 'rodou', 'rodado', 'rodadas'],
#  'necessit': ['necessitava',
#   'necessita',
#   'necessitamos',
#   'necessitem',
#   'necessitados',
#   'necessitado'],
#  'auxíli': ['auxílio'],
#  'médic': ['médico', 'médicos', 'médicas', 'médica', 'médici'],
#  'const': ['constante', 'constantemente', 'constantes', 'constam', 'constava'],
#  'doenç': ['doença', 'doenças'],
#  'portugues': ['portugueses'],
#  'controvers': ['controverso', 'controversa'],
#  'vasc': ['vasco'],
#  'gam': ['gama', 'game', 'games'],
#  'particip': ['participava',
#   'participando',
#   'participação',
#   'participante',
#   'participantes',
#   'participaram',
#   'participa',
#   'participar',
#   'participam',
#   'participado',
#   'participará',
#   'participasse',
#   'participou',
#   'participarem',
#   'participo'],
#  'ativ': ['atividades',
#   'ativamente',
#   'ativando',
#   'ativa',
#   'ativistas',
#   'atividade',
#   'ativo',
#   'ativado',
#   'ativista',
#   'ativar',
#   'ativismo',
#   'ativos',
#   'ativismos',
#   'ativaram',
#   'ativá'],
#  'administr': ['administrativas',
#   'administração',
#   'administrando',
#   'administra',
#   'administrada',
#   'administrativa',
#   'administrado',
#   'administrativo',
#   'administrar',
#   'administrará',
#   'administrativos',
#   'administradores',
#   'administradora',
#   'administradas'],
#  '1967': ['1967'],
#  'ingress': ['ingressou', 'ingressos', 'ingressaram', 'ingressar', 'ingresso'],
#  'dire': ['diretor', 'diretora', 'diretores', 'diretiva'],
#  'ocup': ['ocupou',
#   'ocupam',
#   'ocupa',
#   'ocupo',
#   'ocupada',
#   'ocupante',
#   'ocupados',
#   'ocupar',
#   'ocupado',
#   'ocupando',
#   'ocupava',
#   'ocupadas',
#   'ocuparia',
#   'ocupará',
#   'ocuparam'],
#  '2003': ['2003'],
#  '2008': ['2008'],
#  '2015': ['2015'],
#  'fim': ['fim', 'fins'],
#  '2017': ['2017'],
#  'déc': ['década', 'décima', 'décadas', 'décimos', 'décimo'],
#  'vic': ['vice'],
#  'mai': ['maiores', 'maior', 'maio', 'maia'],
#  'conqu': ['conquistas', 'conquista'],
#  '1997': ['1997'],
#  '2000': ['2000'],
#  '1998': ['1998'],
#  '1989': ['1989'],
#  'mandat': ['mandato', 'mandatos', 'mandatário', 'mandatários'],
#  'ped': ['pedido',
#   'pedir',
#   'pediu',
#   'pediram',
#   'pede',
#   'pedimos',
#   'pedia',
#   'pedem',
#   'pedindo',
#   'pedidos',
#   'pedi',
#   'pedira',
#   'pedirem',
#   'pediam'],
#  'estend': ['estendeu',
#   'estendem',
#   'estendidas',
#   'estendidos',
#   'estender',
#   'estenderá',
#   'estende'],
#  'influ': ['influência', 'influentes', 'influente'],
#  'eleit': ['eleito', 'eleita', 'eleitos', 'eleitas'],
#  'vez': ['vezes', 'vez'],
#  'deput': ['deputado', 'deputados', 'deputada', 'deputadas', 'deputação'],
#  'feder': ['federal', 'federados', 'federais', 'federação', 'federações'],
#  '1994': ['1994'],
#  '2002': ['2002'],
#  'conhec': ['conhecido',
#   'conhecerão',
#   'conhecedor',
#   'conhece',
#   'conhecidas',
#   'conhecer',
#   'conhecem',
#   'conheceram',
#   'conheceu',
#   'conhecimento',
#   'conheci',
#   'conhecida',
#   'conhecidos',
#   'conhecia',
#   'conhecíamos',
#   'conhecemos',
#   'conhecê',
#   'conhecedores'],
#  'polêm': ['polêmicas', 'polêmica', 'polêmico', 'polêmicos'],
#  'mirand': ['miranda'],
#  'joã': ['joão'],
#  'havelang': ['havelange'],
#  'brig': ['briga', 'brigadas', 'brigas', 'brigadeiro', 'brigou', 'brigavam'],
#  'justiç': ['justiça'],
#  'red': ['rede', 'redes', 'reda', 'redação', 'redações'],
#  'glob': ['globo',
#   'global',
#   'globalizado',
#   'globais',
#   'globalmente',
#   'globalismo'],
#  'estamp': ['estampou', 'estampa'],
#  'emis': ['emissora', 'emissoras'],
#  'concorr': ['concorrente',
#   'concorrência',
#   'concorreria',
#   'concorrer',
#   'concorria',
#   'concorrentes',
#   'concorreu'],
#  'sbt': ['sbt'],
#  'uniform': ['uniforme'],
#  'ídol': ['ídolo', 'ídolos'],
#  'sen': ['senador', 'senado', 'senadora', 'senadores', 'senai'],
#  'lament': ['lamentou',
#   'lamentável',
#   'lamentações',
#   'lamentáveis',
#   'lamenta',
#   'lamentava'],
#  'falec': ['falecimento', 'falecido', 'faleceu', 'faleceram', 'falecidos'],
#  'pouqu': ['pouquíssimos', 'pouquíssimo'],
#  'amig': ['amigos', 'amigo', 'amiga', 'amigas', 'amigável'],
#  'fum': ['fumarmos', 'fumar', 'fuma'],
#  'charut': ['charuto'],
#  'junt': ['juntos',
#   'junto',
#   'juntamente',
#   'juntas',
#   'juntou',
#   'junta',
#   'juntada',
#   'juntando',
#   'juntem',
#   'juntaram'],
#  'desafet': ['desafeto'],
#  'solidariedad': ['solidariedade'],
#  'famíl': ['família', 'famílias'],
#  'decret': ['decretou', 'decretado', 'decreto'],
#  'lut': ['luto',
#   'luta',
#   'lutas',
#   'lutar',
#   'lutam',
#   'lutando',
#   'lutavam',
#   'lutem',
#   'lutou'],
#  'ofic': ['oficial', 'oficiais', 'oficialmente'],
#  'cancel': ['cancelou',
#   'cancelara',
#   'cancelar',
#   'cancelado',
#   'cancelamento',
#   'cancelados'],
#  'indeniz': ['indenizará'],
#  'vítim': ['vítimas', 'vítima'],
#  'viol': ['violência',
#   'violada',
#   'violação',
#   'violasse',
#   'violações',
#   'violão',
#   'violados',
#   'violou',
#   'violências',
#   'violadores',
#   'violem'],
#  'sex': ['sexual', 'sexualmente', 'sexo', 'sexuais', 'sexismo'],
#  'infantil': ['infantil'],
#  'pris': ['prisão', 'prisional', 'prisões'],
#  'denúnc': ['denúncias', 'denúncia'],
#  'abus': ['abuso',
#   'abusando',
#   'abusado',
#   'abusa',
#   'abusador',
#   'abusar',
#   'abusada',
#   'abusos',
#   'abusadores',
#   'abusava'],
#  '1979': ['1979'],
#  '1990': ['1990'],
#  'trabalh': ['trabalhou',
#   'trabalho',
#   'trabalha',
#   'trabalhista',
#   'trabalhos',
#   'trabalhar',
#   'trabalhava',
#   'trabalhando',
#   'trabalhador',
#   'trabalhavam',
#   'trabalhadores',
#   'trabalharei',
#   'trabalham',
#   'trabalhismo',
#   'trabalharmos',
#   'trabalhado',
#   'trabalharam',
#   'trabalhistas',
#   'trabalhei',
#   'trabalhadas',
#   'trabalhará',
#   'trabalhávamos',
#   'trabalhamos',
#   'trabalhadoras'],
#  'city': ['city'],
#  'crew': ['crewe'],
#  'alexandr': ['alexandra', 'alexandre', 'alexandria'],
#  'tribun': ['tribunal', 'tribunais', 'tribunas'],
#  'liverpool': ['liverpool'],
#  'bennell': ['bennell'],
#  'comet': ['cometeu',
#   'cometidos',
#   'cometida',
#   'cometer',
#   'cometendo',
#   'cometido',
#   'cometimento',
#   'cometeram',
#   'comete',
#   'cometidas'],
#  'idad': ['idades', 'idade'],
#  'inform': ['informa',
#   'informação',
#   'informantes',
#   'informou',
#   'informado',
#   'informaram',
#   'informações',
#   'informando',
#   'informes',
#   'informais',
#   'informal',
#   'informar',
#   'informatização',
#   'informados'],
#  'investig': ['investigação',
#   'investigando',
#   'investigar',
#   'investigações',
#   'investigadores',
#   'investiga',
#   'investigam',
#   'investigado',
#   'investigados',
#   'investigou',
#   'investigada',
#   'investigativo',
#   'investigador'],
#  'independ': ['independente',
#   'independência',
#   'independentemente',
#   'independentes'],
#  'revel': ['revelou',
#   'revelados',
#   'revelam',
#   'revela',
#   'revelar',
#   'reveladas',
#   'revelando',
#   'revelada',
#   'revelado',
#   'revelei',
#   'revelações'],
#  'outr': ['outro', 'outra', 'outros', 'outras', 'outrora'],
#  'john': ['john'],
#  'broom': ['broome'],
#  'cuj': ['cujas', 'cujo', 'cuja', 'cujos'],
#  'supost': ['supostas', 'suposta', 'supostos', 'supostamente', 'suposto'],
#  'eleg': ['elegíveis',
#   'elegância',
#   'elege',
#   'elegeu',
#   'elegermos',
#   'elegeram',
#   'elegem'],
#  'compens': ['compensação', 'compensações', 'compensar'],
#  'financ': ['financeira',
#   'financeiras',
# ...
#   'definição',
#   'definia',
#   'defina',
#   'definir',
#   'defini',
#   'definidos',
#   'definindo'],
#  'lad': ['lado', 'lados'],
#  'chav': ['chave', 'chavismo', 'chavistas', 'chaves'],
#  'opost': ['oposto', 'oposta', 'opostos'],
#  'abril': ['abril'],
#  'mê': ['mês'],
#  'conform': ['conforme', 'conformou'],
#  'chave': ['chaveamento'],
#  'madr': ['madri', 'madrinha'],
#  'junh': ['junho'],
#  'mand': ['mandante',
#   'mandar',
#   'manda',
#   'mandam',
#   'mandá',
#   'mandado',
#   'mandando',
#   'mandou',
#   'mandantes',
#   'mandava',
#   'mandaram',
#   'mandasse'],
#  'neutr': ['neutro', 'neutra'],
#  'her': ['here'],
#  'the': ['the', 'theo'],
#  'road': ['road'],
#  'pot': ['potências', 'potência'],
#  'europe': ['europeias', 'europeia'],
#  'estiv': ['estiveram',
#   'estivesse',
#   'estivessem',
#   'estiver',
#   'estiverem',
#   'estivera',
#   'estive'],
#  '2007': ['2007'],
#  'algoz': ['algozes'],
#  'miss': ['missões', 'missão', 'missa'],
#  'difer': ['diferentes', 'diferente', 'diferentemente'],
#  'favorit': ['favorita', 'favoritos'],
#  'agreg': ['agregado', 'agregadores', 'agregam'],
#  'soment': ['somente'],
#  'quatr': ['quatro'],
#  'psg': ['psg'],
#  'rest': ['restante',
#   'resto',
#   'restos',
#   'restam',
#   'resta',
#   'restem',
#   'restava',
#   'restou',
#   'restavam',
#   'restantes',
#   'restará'],
#  'protagoniz': ['protagonizou', 'protagonizaram'],
#  'na': ['nas'],
#  'saiu': ['saiu'],
#  'começ': ['começado',
#   'começando',
#   'começava',
#   'começa',
#   'começam',
#   'começou',
#   'começará',
#   'começo',
#   'começaram',
#   'começar',
#   'começassem',
#   'começamos',
#   'começaríamos',
#   'começavam',
#   'começarem',
#   'começarão',
#   'começasse'],
#  'carr': ['carreira',
#   'carrinho',
#   'carreiras',
#   'carri',
#   'carro',
#   'carros',
#   'carrinhos'],
#  'exager': ['exagero',
#   'exagerar',
#   'exageros',
#   'exagerado',
#   'exagerados',
#   'exagerada'],
#  'quas': ['quase'],
#  'algum': ['alguns', 'alguma', 'algum', 'algumas'],
#  'insist': ['insistem',
#   'insistiu',
#   'insiste',
#   'insista',
#   'insistência',
#   'insistir',
#   'insistiam'],
#  'visit': ['visitante',
#   'visitas',
#   'visitado',
#   'visitá',
#   'visitantes',
#   'visitar',
#   'visitei',
#   'visitou',
#   'visita',
#   'visitadas'],
#  'incrédul': ['incrédulo'],
#  'reescrev': ['reescreveriam', 'reescrever', 'reescreverem'],
#  'sassuol': ['sassuolo'],
#  'escantei': ['escanteio'],
#  'alucin': ['alucinaram', 'alucinado', 'alucinação'],
#  'mão': ['mão', 'mãos', 'mães'],
#  'rost': ['rosto', 'rostos'],
#  'imit': ['imitando', 'imitá', 'imito', 'imitar', 'imitação'],
#  'fam': ['famosa', 'famoso', 'famosas', 'fama', 'famosos'],
#  'másc': ['máscara'],
#  'dybal': ['dybala'],
#  'invent': ['inventada',
#   'inventado',
#   'inventar',
#   'inventou',
#   'inventariam',
#   'inventamos'],
#  'esper': ['esperando',
#   'esperava',
#   'esperar',
#   'espero',
#   'esperado',
#   'esperamos',
#   'espera',
#   'esperou',
#   'esperada',
#   'esperavam',
#   'esperadas',
#   'esperávamos',
#   'esperassem',
#   'esperará'],
#  'donn': ['donna'],
#  'humild': ['humilde', 'humildes'],
#  'afirm': ['afirmam',
#   'afirmou',
#   'afirma',
#   'afirmava',
#   'afirmar',
#   'afirmado',
#   'afirmações',
#   'afirmando',
#   'afirmação',
#   'afirmaram',
#   'afirmavam'],
#  'membr': ['membros', 'membro'],
#  'omit': ['omitindo', 'omitido', 'omitiram'],
#  'narcis': ['narcisista'],
#  'estrel': ['estrela', 'estrelado', 'estrelados', 'estrelas'],
#  'torn': ['tornou',
#   'tornar',
#   'torneiras',
#   'tornaram',
#   'tornasse',
#   'torna',
#   'torno',
#   'tornado',
#   'tornassem',
#   'tornam',
#   'torne',
#   'tornava',
#   'tornando',
#   'tornariam',
#   'tornaria',
#   'tornarem',
#   'tornada',
#   'tornem',
#   'tornará'],
#  'séri': ['série', 'séries', 'sério', 'sérios'],
#  'contrat': ['contratos',
#   'contratação',
#   'contratar',
#   'contratada',
#   'contratam',
#   'contratou',
#   'contratações',
#   'contrato',
#   'contratados',
#   'contratual',
#   'contratuais'],
#  'just': ['justamente', 'justa', 'justo', 'just'],
#  'consecu': ['consecutivos'],
#  'estagn': ['estagnação', 'estagnada'],
#  'competi': ['competitiva', 'competitivos'],
#  'feliz': ['feliz', 'felizes', 'felizmente'],
#  'capaz': ['capaz', 'capazes'],
#  'metropolit': ['metropolitano', 'metropolitana', 'metropolitanas'],
#  'oper': ['operação',
#   'operário',
#   'opera',
#   'operar',
#   'operam',
#   'operações',
#   'operadora',
#   'operado',
#   'operadoras'],
#  'cr7': ['cr7'],
#  'gram': ['gramado', 'grama'],
#  'carreg': ['carrega',
#   'carregava',
#   'carregados',
#   'carregadas',
#   'carregadoras',
#   'carregando',
#   'carregar',
#   'carregado',
#   'carregadores'],
#  'ombr': ['ombros'],
#  'relanç': ['relançamento'],
#  'crepuscul': ['crepuscular'],
#  'calci': ['calcio'],
#  'cidad': ['cidade', 'cidadãos', 'cidades', 'cidadezinha', 'cidadão'],
#  'definh': ['definhava'],
#  'recus': ['recusa',
#   'recusado',
#   'recusam',
#   'recusava',
#   'recusar',
#   'recusada',
#   'recusou',
#   'recusaram',
#   'recusei',
#   'recusarem',
#   'recusando'],
#  'govern': ['governo',
#   'governantes',
#   'governos',
#   'governado',
#   'governista',
#   'governismo',
#   'governadora',
#   'governada',
#   'governar',
#   'governou',
#   'governador',
#   'governa',
#   'governadas',
#   'governadores',
#   'governabilidade',
#   'governaram',
#   'governistas',
#   'governante',
#   'governava'],
#  'projet': ['projetos',
#   'projeto',
#   'projetam',
#   'projetar',
#   'projetado',
#   'projetados',
#   'projeta',
#   'projete',
#   'projetou',
#   'projetada'],
#  'tal': ['tais', 'tal'],
#  'tr': ['trem', 'trava', 'traremos', 'trarão'],
#  'veloc': ['velocidade'],
#  'olímp': ['olímpicos', 'olímpica', 'olímpico'],
#  '2026': ['2026'],
#  'planej': ['planejados',
#   'planejadas',
#   'planejamento',
#   'planeja',
#   'planejavam',
#   'planejam'],
#  'restaur': ['restaurar'],
#  'antig': ['antiga', 'antigos', 'antigas', 'antigo'],
#  'capit': ['capital',
#   'capitalismo',
#   'capitalista',
#   'capitais',
#   'capitalização',
#   'capita'],
#  'element': ['elemento', 'elementos', 'elementar'],
#  'estratég': ['estratégico',
#   'estratégia',
#   'estratégica',
#   'estratégicos',
#   'estratégias'],
#  'vitrin': ['vitrine', 'vitrines'],
#  '360': ['360'],
#  'grau': ['graus', 'grau'],
#  'cust': ['custou',
#   'custear',
#   'custo',
#   'custa',
#   'custava',
#   'custos',
#   'custas',
#   'custado',
#   'custar',
#   'custe',
#   'custoso',
#   'custam'],
#  '100': ['100'],
#  'eur': ['euros', 'euro'],
#  'cerc': ['cerca',
#   'cercado',
#   'cercados',
#   'cercam',
#   'cercava',
#   'cercaram',
#   'cercou',
#   'cercadas'],
#  '421': ['421'],
#  '357': ['357'],
#  'especi': ['especialistas',
#   'especialista',
#   'especializada',
#   'especializados',
#   'especialização'],
#  'aument': ['aumento',
#   'aumentou',
#   'aumentar',
#   'aumentos',
#   'aumentam',
#   'aumenta',
#   'aumente',
#   'aumentava',
#   'aumentado',
#   'aumentando',
#   'aumentem',
#   'aumentaria',
#   'aumentaram'],
#  'preç': ['preço', 'preços'],
#  'assin': ['assinando',
#   'assinados',
#   'assinava',
#   'assinam',
#   'assinar',
#   'assinou',
#   'assinada',
#   'assinado',
#   'assinaram',
#   'assinem'],
#  'comerc': ['comerciais', 'comercial', 'comercialmente'],
#  'espec': ['especialmente', 'especial', 'especiais'],
#  'mod': ['modo', 'moda'],
#  'imag': ['imagem', 'imagens'],
#  'cruc': ['crucial', 'cruciais'],
#  'base': ['baseada', 'baseia', 'baseadas', 'baseado', 'baseados'],
#  'quest': ['questão', 'questões', 'questionar', 'questiona'],
#  'sombr': ['sombra', 'sombras', 'sombrias', 'sombria'],
#  'dinh': ['dinheiro'],
#  'vim': ['vimos', 'vim'],
#  'bellinazz': ['bellinazzo'],
#  'autor': ['autor',
#   'autora',
#   'autores',
#   'autoria',
#   'autorais',
#   'autorização',
#   'autorizado',
#   'autoral',
#   'autorizados',
#   'autorizar'],
#  'best': ['best'],
#  'sell': ['seller'],
#  'escritóri': ['escritórios', 'escritório'],
#  'bunk': ['bunker'],
#  'blind': ['blindado', 'blindada', 'blindados', 'blindar'],
#  'prov': ['prova',
#   'provas',
#   'provar',
#   'provável',
#   'provou',
#   'provada',
#   'provedora'],
#  'despert': ['despertaram',
#   'despertam',
#   'despertou',
#   'desperta',
#   'despertado',
#   'despertando',
#   'despertar',
#   'despertadas',
#   'despertava'],
#  'enorm': ['enorme', 'enormemente', 'enormes', 'enormidade'],
#  'cot': ['cotações', 'cota', 'cotação', 'cotados', 'cotia', 'cotas'],
#  'empr': ['empresa', 'empresas'],
#  'me': ['meados'],
#  'caír': ['caíram'],
#  'reabert': ['reabertura', 'reabertos'],
#  '2009': ['2009'],
#  'la': ['las'],
#  'veg': ['vegas', 'vega'],
#  'preocup': ['preocupou',
#   'preocupados',
#   'preocupavam',
#   'preocupava',
#   'preocupação',
#   'preocupadas',
#   'preocupada',
#   'preocupado',
#   'preocupar',
#   'preocupantes',
#   'preocupa',
#   'preocupações',
#   'preocupamos',
#   'preocupam'],
#  'patrocin': ['patrocinadora', 'patrocinadores'],
#  'profund': ['profundamente',
#   'profundezas',
#   'profundos',
#   'profundo',
#   'profunda',
#   'profundidade',
#   'profundas'],
#  'nik': ['nike'],
#  'monitor': ['monitorando', 'monitoramento', 'monitoram', 'monitorar'],
#  'situ': ['situação',
#   'situações',
#   'situa',
#   'situou',
#   'situando',
#   'situar',
#   'situado'],
#  'trem': ['tremer', 'tremendo'],
#  'exércit': ['exército'],
#  'advog': ['advogados', 'advogado', 'advogada'],
#  'execu': ['executivos', 'executivo', 'executiva', 'executores'],
#  'caminh': ['caminho',
#   'caminhar',
#   'caminhadas',
#   'caminhos',
#   'caminhões',
#   'caminha',
#   'caminhada',
#   'caminhando'],
#  'difícil': ['difícil'],
#  'aceit': ['aceitou',
#   'aceitarem',
#   'aceito',
#   'aceitassem',
#   'aceitável',
#   'aceitado',
#   'aceitando',
#   'aceitação',
#   'aceitar',
#   'aceitei',
#   'aceitamos',
#   'aceitos',
#   'aceita',
#   'aceitaram',
#   'aceitáveis',
#   'aceite'],
#  'crim': ['crime', 'crimes', 'criminal', 'criminalmente'],
#  'fiscal': ['fiscal', 'fiscalizar', 'fiscais', 'fiscalização'],
#  'baix': ['baixa',
#   'baixam',
#   'baixas',
#   'baixista',
#   'baixar',
#   'baixos',
#   'baixo',
#   'baixada',
#   'baixíssima'],
#  'recess': ['recesso', 'recessões', 'recessão', 'recessivos'],
#  'fest': ['festas', 'festa', 'festiva'],
#  'tuít': ['tuíte', 'tuítes'],
#  'sintax': ['sintaxe'],
#  'própr': ['própria', 'próprias'],
#  'andre': ['andrea'],
#  'agnell': ['agnelli'],
#  'total': ['total', 'totalmente', 'totalidade'],
#  'olh': ['olhar',
#   'olhos',
#   'olho',
#   'olhava',
#   'olhada',
#   'olha',
#   'olhou',
#   'olhando',
#   'olharmos',
#   'olhares',
#   'olheiros',
#   'olhe',
#   'olham',
#   'olhassem'],
#  'lhe': ['lhe', 'lhes'],
#  'assunt': ['assunto', 'assuntos'],
#  'sens': ['sensação',
#   'sensações',
#   'sensuais',
#   'sensível',
#   'sensíveis',
#   'senso',
#   'sense'],
#  'escândal': ['escândalo', 'escândalos'],
#  'mont': ['montado',
#   'montados',
#   'montagens',
#   'montou',
#   'montagem',
#   'montura',
#   'montador',
#   'montes',
#   'montantes',
#   'montante',
#   'monta',
#   'montadas',
#   'montadoras',
#   'montada',
#   'montadora',
#   'monte',
#   'monteiro'],
#  'promot': ['promotoria', 'promotores', 'promotora', 'promotor'],
#  'solicit': ['solicitado',
#   'solicitaram',
#   'solicita',
#   'solicitou',
#   'solicitaria',
#   'solicitação',
#   'solicitando',
#   'solicitações',
#   'solicitantes'],
#  'test': ['teste',
#   'testar',
#   'testa',
#   'testamento',
#   'testes',
#   'testado',
#   'testou'],
#  'nad': ['nada', 'nadia', 'nadadora', 'nadar', 'nadam', 'nadador'],
#  'pes': ['pesou',
#   'pesares',
#   'peso',
#   'pesar',
#   'pesado',
#   'pesos',
#   'pesados',
#   'pesada',
#   'pese'],
#  'opin': ['opinião', 'opiniões', 'opina', 'opinam'],
#  'númer': ['números', 'número'],
#  'adapt': ['adaptou',
#   'adaptação',
#   'adaptar',
#   'adapta',
#   'adaptando',
#   'adaptadas',
#   'adaptações',
#   'adaptada',
#   'adaptarem',
#   'adaptasse'],
#  'perfeit': ['perfeitamente', 'perfeito', 'perfeita'],
#  'rotin': ['rotinas', 'rotina', 'rotineiras', 'rotineiros'],
#  'allegr': ['allegri'],
#  'aval': ['avalia', 'aval', 'avaliava', 'avaliam'],
#  'sistem': ['sistemas', 'sistema'],
#  'evid': ['evidente', 'evidências', 'evidentemente', 'evidência', 'evidentes'],
#  'vazi': ['vazio', 'vazios'],
#  'vesti': ['vestiário'],
#  'queix': ['queixas', 'queixa', 'queixo', 'queixara'],
#  'inclusiv': ['inclusive'],
#  'font': ['fontes', 'fonte'],
#  'surpreend': ['surpreendidos',
#   'surpreendentemente',
#   'surpreendente',
#   'surpreenderia',
#   'surpreendeu',
#   'surpreenderam'],
#  'humildad': ['humildade'],
#  'din': ['dino'],
#  'zoff': ['zoff'],
#  'lend': ['lendário', 'lenda', 'lendas', 'lendo'],
#  'acredit': ['acredita',
#   'acreditando',
#   'acreditaram',
#   'acreditem',
#   'acredito',
#   'acreditar',
#   'acreditam',
#   'acreditarem',
#   'acreditava',
#   'acreditamos',
#   'acreditavam',
#   'acredite'],
#  'rentabiliz': ['rentabilizando'],
#  'nível': ['nível', 'níveis'],
#  'emoc': ['emocional'],
#  'posi': ['positiva', 'positivas', 'positivo', 'positivos'],
#  'contribu': ['contribuído',
#   'contribui',
#   'contribuíram',
#   'contribuição',
#   'contribuições',
#   'contribuam',
#   'contribuiu',
#   'contribuindo',
#   'contribuem',
#   'contributiva',
#   'contribuir'],
#  'demonstr': ['demonstrando',
#   'demonstra',
#   'demonstrar',
#   'demonstrada',
#   'demonstram',
#   'demonstrou',
#   'demonstração',
#   'demonstraram',
#   'demonstrado',
#   'demonstramos'],
#  'lideranç': ['liderança', 'lideranças'],
#  'determin': ['determinada',
#   'determinaram',
#   'determinações',
#   'determinam',
#   'determinado',
#   'determine',
#   'determinar',
#   'determinante',
#   'determinados',
#   'determinadas',
#   'determinou',
#   'determinação',
#   'determina'],
#  'troux': ['trouxe', 'trouxeram'],
#  'talv': ['talvez'],
#  'lem': ['lema', 'leme'],
#  'escrit': ['escrito',
#   'escritura',
#   'escritas',
#   'escritos',
#   'escrita',
#   'escrituras'],
#  'dialet': ['dialeto'],
#  'piemont': ['piemontês', 'piemontesa'],
#  'signif': ['significa'],
#  'exag': ['exageremos', 'exageram'],
#  'quintess': ['quintessência'],
#  'discr': ['discrição'],
#  'burgu': ['burguesa'],
#  'ador': ['adora',
#   'adoraria',
#   'adoraram',
#   'adoramos',
#   'adorou',
#   'adoro',
#   'adoram'],
#  'vid': ['vida', 'vidas'],
#  'torin': ['torino'],
#  'angell': ['angelli'],
#  'sorri': ['sorriem'],
#  'revitaliz': ['revitalize'],
#  'niss': ['nisso'],
#  'exclam': ['exclama', 'exclamar', 'exclamaria'],
#  'giac': ['giacomo'],
#  'quitand': ['quitanda'],
#  'centr': ['centro', 'central', 'centros', 'centra', 'centrais', 'centrista'],
#  'apont': ['apontando',
#   'apontar',
#   'aponta',
#   'apontam',
#   'apontou',
#   'apontado',
#   'apontaram',
#   'apontem',
#   'apontada'],
#  'caix': ['caixa', 'caixas', 'caixão'],
#  'registr': ['registradora',
#   'registrou',
#   'registro',
#   'registros',
#   'registradas',
#   'registrar',
#   'registrada',
#   'registrando',
#   'registrados',
#   'registrado',
#   'registraram'],
#  'acompanh': ['acompanhavam',
#   'acompanhado',
#   'acompanha',
#   'acompanhar',
#   'acompanhante',
#   'acompanhasse',
#   'acompanhá',
#   'acompanhou',
#   'acompanham',
#   'acompanhava',
#   'acompanhada',
#   'acompanharam',
#   'acompanhe',
#   'acompanhadas',
#   'acompanhados',
#   'acompanhando'],
#  'mov': ['movimentos',
#   'movimento',
#   'moveram',
#   'movidos',
#   'move',
#   'mover',
#   'moveu',
#   'movem'],
#  'isol': ['isolado',
#   'isolados',
#   'isolamento',
#   'isolada',
#   'isoladas',
#   'isolantes',
#   'isolante',
#   'isola',
#   'isolando'],
#  'mans': ['mansão'],
#  'colin': ['colina', 'colinas', 'colin'],
#  'plen': ['plena', 'plenamente', 'pleno', 'plenário'],
#  'ra': ['razões', 'razão'],
#  'seguranç': ['segurança'],
#  'resid': ['residencial',
#   'residência',
#   'residentes',
#   'residem',
#   'residir',
#   'residuais',
#   'residências',
#   'residente',
#   'residindo'],
#  'mandr': ['mandria'],
#  'proc': ['procura'],
#  'aríet': ['aríete'],
#  'rua': ['ruas', 'rua'],
#  'giovann': ['giovanni'],
#  'lun': ['luna'],
#  'histori': ['historiador', 'historiadores', 'historiadora', 'historiadoras'],
#  'atol': ['atolada'],
#  'econôm': ['econômica', 'econômicas', 'econômico', 'econômicos'],
#  'mil': ['milão', 'mil'],
#  'vig': ['vigor', 'vigia', 'vigiam', 'vigência', 'vigora', 'viga'],
#  'alegr': ['alegrar',
#   'alegre',
#   'alegres',
#   'alegria',
#   'alegram',
#   'alegrou',
#   'alegremente'],
#  'deprim': ['deprimida', 'deprimem'],
#  'fiat': ['fiat'],
#  'sustent': ['sustenta',
#   'sustentam',
#   'sustentada',
#   'sustentável',
#   'sustentar',
#   'sustentação',
#   'sustentáveis',
#   'sustentavam',
#   'sustentabilidade',
#   'sustentava'],
#  'pil': ['pilares', 'pilar'],
#  'café': ['café', 'cafés'],
#  'lavazz': ['lavazza'],
#  'impression': ['impressionante',
#   'impressionantes',
#   'impressionado',
#   'impressionam',
#   'impressionados'],
#  'mus': ['museu', 'museus'],
#  'egípci': ['egípcio'],
#  'president': ['presidenta', 'president'],
#  'evelin': ['evelina'],
#  'christillin': ['christillin'],
#  'dicotom': ['dicotomia'],
#  ...}

# %% [markdown]
# #### Falsos Positivos
#
# 'dur': ['durante','duro']
# 'ele': ['ele', 'eleição']
# 'tem': ['tem', 'teme']
#  'di': ['diante', 'diariamente', 'diaria']
# 'qu': ['quando', 'quem', 'quer', 'queríamos', 'quai']
# 'gest': ['gesto','gestação']
# 'cert': ['certas', 'certidão']
# 'cor': ['cores', 'coro']
# 'pi': ['pior', 'piada']
# 'import': [ 'importância','importação']
#
# Esses falsos positivos fazem com que o motor de busca retorne resultados que não correspondem ao que o usuário estava buscando.

# %% [markdown]
# #### Falsos negativos
#
# diz: ['diz','dizer','dizem'],
# diss: ['disse', 'disso', 'disseram', 'dissessem']
#
# tecnolog: ['tecnologia', 'tecnologias']
# tecnológ: ['tecnológicos', 'tecnológico', 'tecnológica', 'tecnológicas']
#
# telefon: ['telefone', 'telefonia', 'telefonam', 'telefones']
# telefonem: ['telefonema', 'telefonemas']
#
# terc: ['terceira', 'terceiro', 'terceiros']
# terceir: ['terceirizado', 'terceirizada', 'terceirização']
#
# tol: ['toleram']
# toler: ['tolerantes', 'tolerância', 'tolerante', 'tolerada', 'tolerar']
#
# tort: ['tortura', 'tortas', 'torturas', 'tortuosa']
# tortur: ['torturado', 'torturadores', 'torturaram']
#
# total: ['total', 'totalmente', 'totalidade']
# totalit: ['totalitários', 'totalitário']
#
# trad: ['tradição', 'tradições']
# tradic: ['tradicionais', 'tradicional', 'tradicionalmente']
#
# tranquil: ['tranquilo', 'tranquilidade', 'tranquila', 'tranquilas']
# tranquiliz: ['tranquiliza', 'tranquilizava']
#
# tribut: ['tributos', 'tributação']
# tributár: ['tributárias', 'tributária']

# %% [markdown]
# ### Questão 4:

# %%
pr_prob = table42['Pr(%)'] / 100
c = np.median(table42['r.Pr'])
table42['c'] = c / pr_prob
message = "the best c parameter is %f" % c
message
# Out:
# 'the best c parameter is 0.138524'

# %%
f, ax = plt.subplots()
ax.set(xscale="log", yscale="log")
plt.plot(table42['r'], table42['Freq'], linestyle='None', marker='o')
plt.plot(table42['bestc'], table42['Freq'], linestyle='-', marker='None')
plt.xlabel('Ranking')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bestc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-57ac5634d7dd> in <module>()
#       2 ax.set(xscale="log", yscale="log")
#       3 plt.plot(table42['r'], table42['Freq'], linestyle='None', marker='o')
# ----> 4 plt.plot(table42['bestc'], table42['Freq'], linestyle='-', marker='None')
#       5 plt.xlabel('Ranking')
#       6 plt.ylabel('Frequency')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bestc'
